# %%
import requests
import pdfplumber
import pandas as pd

# %%
# URL du PDF à télécharger
url = "https://www.iledefrance-mobilites.fr/medias/portail-idfm/da6142b2-d07c-474a-8aff-18c3cb9e0291_Contrat+IDFM_SNCF_Annexes_VDef_HorsConfidentielles.pdf"

# Nom du fichier local où le PDF sera enregistré
pdf_filename = "contrat_idfm_sncf.pdf"

# Étape 1 : Télécharger le fichier PDF
response = requests.get(url)
if response.status_code == 200:
    with open(pdf_filename, 'wb') as f:
        f.write(response.content)
    print(f"Le fichier PDF a été téléchargé et enregistré sous le nom : {pdf_filename}")
else:
    print(f"Erreur lors du téléchargement du PDF. Statut: {response.status_code}")
# Out:
# Le fichier PDF a été téléchargé et enregistré sous le nom : contrat_idfm_sncf.pdf

# %%
# Étape 2 : Ouvrir le fichier PDF et extraire les tableaux des pages 392 et 393
with pdfplumber.open(pdf_filename) as pdf:
    # Extraire les pages 392 et 393 (index starts from 0, so 391 and 392)
    page_392 = pdf.pages[167]
    page_393 = pdf.pages[168]

    # Extraire les tableaux
    tables_392 = page_392.extract_tables()
    tables_393 = page_393.extract_tables()

# %%
# Étape 3 : Manipuler les données extraites
if tables_392 and tables_393:
    df_392 = pd.DataFrame(tables_392[0])
    df_393 = pd.DataFrame(tables_393[0])

    # Concaténer les deux tables
    df_total = pd.concat([df_392, df_393], ignore_index=True)

    # Afficher le tableau final
    #print(df_total)

    # Sauvegarder en fichier Excel
    df_total.to_excel('tableau_extrait.xlsx', index=False)
    print("Le tableau a été extrait et enregistré dans 'tableau_extrait.xlsx'.")
else:
    print("Impossible d'extraire des tableaux des pages spécifiées.")
# Out:
# Le tableau a été extrait et enregistré dans 'tableau_extrait.xlsx'.

# %%
df_total
# Out:
#                                       0            1     2   \
# 0                            Thématiques
# 1                                   None  Thématiques  None
# 2                                   None         None  None
# 3                                   None         None  None
# 4   Qualité de\nl’offre /\nPonctualité**         None    50
# 5                 Information\nvoyageurs         None    12
# 6                                   None         None  None
# 7                                   None         None  None
# 8                                   None         None  None
# 9                                   None         None  None
# 10                                  None         None  None
# 11                                  None         None  None
# 12                   Vente/\nvalidations         None     4
# 13                                  None         None  None
# 14                                  None         None  None
# 15                            Elévatique         None     3
# 16                                  None         None  None
# 17                                  None         None  None
# 18                                  None         None  None
# 19                                  None         None  None
# 20                                  None         None  None
# 21                              Propreté         None     3
# 22                                  None         None  None
# 23                    Contact\nvoyageurs         None     2
# 24                                  None         None  None
# 25                                  None         None  None
# 26                                Sûreté         None   0,5
# 27                                  None         None  None
# 28                             Noctilien          0,5  0,5%
# 29                                  None         None  None
# 30                                  None         None  None
# 31                                  None         None  None
# 32                                  None         None  None
# 33                                  None         None  None
# 34                                  None         None  None
# 35                                  None         None  None
# 36             Perception des\nvoyageurs           25   25%
# 37                                 TOTAL          100  100%
#
#                                             3       4   \
# 0                              Montant (M€) et    None
# 1                                  poids de la    None
# 2                              thématique dans    None
# 3                               le système QS*    None
# 4                                         None     50%
# 5                                         None   12,0%
# 6                                         None    None
# 7                                         None    None
# 8                                         None    None
# 9                                         None    None
# 10                                        None    None
# 11                                        None    None
# 12                                        None    4,0%
# 13                                        None    None
# 14                                        None    None
# 15                                        None    3,0%
# 16                                        None    None
# 17                                        None    None
# 18                                        None    None
# 19                                        None    None
# 20                                        None    None
# 21                                        None    3,0%
# 22                                        None    None
# 23                                        None   2,0 %
# 24                                        None    None
# 25                                        None    None
# 26                                        None    0,5%
# 27                                        None    None
# 28    Information statique aux points\nd'arrêt      30
# 29                 Information statique à bord      30
# 30                Information dynamique à bord      30
# 31  Information en situation\nperturbée prévue      60
# 32                         Arrêt aux trottoirs      75
# 33  Disponibilité des plateformes\nélévatrices      20
# 34                      Propreté des véhicules      75
# 35                 Qualité du contact voyageur     180
# 36                          Enquête perception  25 000
# 37                                                None
#
#                                                    5            6         7   \
# 0                                         Indicateurs
# 1                                                None  Indicateurs      None
# 2                                                None         None      None
# 3                                                None         None      None
# 4   Cf ANNEXE I-A-8 « Définition des\nindicateurs ...         None    50 000
# 5   Information statique en situation\nnormale en ...         None     1 200
# 6   Information statique en situation\nnormale à bord         None     1 200
# 7   Information dynamique et sonore\nen situation ...         None     2 400
# 8   Information dynamique et sonore\nen situation ...         None     2 400
# 9                       Information en cas de travaux         None     1 200
# 10                    Information en cas de grèves***         None     1 200
# 11       Information en situation\nperturbée imprévue         None     2 400
# 12            Fonctionnement des automates\nde ventes         None     1 000
# 13       Disponibilité des équipements de\nvalidation         None     1 000
# 14                       Efficacité des lignes de CAB         None     2 000
# 15              Escaliers mécaniques :\ndisponibilité         None       900
# 16  Escaliers mécaniques : délai de\nremise en ser...         None       450
# 17  Escaliers mécaniques : affichage\nde la date d...         None       150
# 18                         Ascenseurs : disponibilité         None       900
# 19           Ascenseurs : délai de remise en\nservice         None       450
# 20  Ascenseurs : affichage de la date\nde remise e...         None       150
# 21                                 Propreté des gares         None     1 500
# 22                                Propreté des trains         None     1 500
# 23               Qualité du contact voyageur en\ngare         None       400
# 24            Qualité du contact voyageur à\ndistance         None       400
# 25  Délai du contact voyageurs en\ngare en 5 mn et...         None     1 200
# 26                  Disponibilité des bornes d’alarme         None       250
# 27  Disponibilité des équipements de\nvidéoprotection         None       250
# 28                                                 6%   Transilien  Annuelle
# 29                                                 6%   Transilien  Annuelle
# 30                                                 6%   Transilien  Annuelle
# 31                                                12%   Transilien  Annuelle
# 32                                                15%   Transilien  Annuelle
# 33                                                 4%   Transilien  Annuelle
# 34                                                15%   Transilien  Annuelle
# 35                                                36%   Transilien  Annuelle
# 36                                               100%        Ligne  Annuelle
# 37                                               None         None      None
#
#                    8     9                                       10  \
# 0     Montant (k€) et  None  Maille et périodicité de\nl’indicateur
# 1            poids de  None                                    None
# 2   l’indicateur dans  None                                    None
# 3       la thématique  None                                    None
# 4                None   50%                        Cf ANNEXE\nI-A-8
# 5                None   10%                                   Ligne
# 6                None   10%                                   Ligne
# 7                None   20%                                   Ligne
# 8                None   20%                                   Ligne
# 9                None   10%                                   Ligne
# 10               None   10%                                   Ligne
# 11               None   20%                                   Ligne
# 12               None   25%                                   Ligne
# 13               None   25%                                   Ligne
# 14               None   50%                                   Ligne
# 15               None   30%                                   Ligne
# 16               None   15%                                   Ligne
# 17               None    5%                                   Ligne
# 18               None   30%                                   Ligne
# 19               None   15%                                   Ligne
# 20               None    5%                                   Ligne
# 21               None   50%                                   Ligne
# 22               None   50%                                   Ligne
# 23               None   20%                                   Ligne
# 24               None   20%                                   Ligne
# 25               None   60%                                   Ligne
# 26               None   50%                                   Ligne
# 27               None   50%                                   Ligne
# 28                NaN   NaN                                     NaN
# 29                NaN   NaN                                     NaN
# 30                NaN   NaN                                     NaN
# 31                NaN   NaN                                     NaN
# 32                NaN   NaN                                     NaN
# 33                NaN   NaN                                     NaN
# 34                NaN   NaN                                     NaN
# 35                NaN   NaN                                     NaN
# 36                NaN   NaN                                     NaN
# 37                NaN   NaN                                     NaN
#
#                    11
# 0                None
# 1                None
# 2                None
# 3                None
# 4   Cf ANNEXE I-A-\n8
# 5           Mensuelle
# 6           Mensuelle
# 7           Mensuelle
# 8           Mensuelle
# 9           Mensuelle
# 10          Mensuelle
# 11          Mensuelle
# 12          Mensuelle
# 13          Mensuelle
# 14          Mensuelle
# 15          Mensuelle
# 16          Mensuelle
# 17          Mensuelle
# 18          Mensuelle
# 19          Mensuelle
# 20          Mensuelle
# 21      Trimestrielle
# 22      Trimestrielle
# 23          Mensuelle
# 24          Mensuelle
# 25          Mensuelle
# 26          Mensuelle
# 27          Mensuelle
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN
# 36                NaN
# 37                NaN

# %%
import pandas as pd

# Data simulée pour répliquer le tableau fourni
data = [
    ["Thématiques", None, "Montant (M€)", None, "poids de la thématique", None, "Indicateurs", None, "Montant (k€)", None, "poids de l’indicateur", None, "Maille et périodicité de l’indicateur"],
    [None, "Thématiques", None, "dans le système QS*", None, None, None, None, None, None, None, None, None],
    ["Qualité de l’offre / Ponctualité", None, 50, None, "50%", "Cf ANNEXE I-A-8", None, 50_000, None, "50%", "Cf ANNEXE I-A-8", "Cf ANNEXE I-A-8"],
    ["Information voyageurs", None, 12, None, "12,0%", "Information statique en gare/station", None, 1_200, None, "10%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Information statique à bord", None, 1_200, None, "10%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Information dynamique en gare/station", None, 2_400, None, "20%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Information dynamique à bord", None, 2_400, None, "20%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Information en cas de travaux", None, 1_200, None, "10%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Information en cas de grèves", None, 1_200, None, "10%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Information en situation perturbée", None, 2_400, None, "20%", "Ligne", "Mensuelle"],
    ["Vente / validations", None, 4, None, "4,0%", "Fonctionnement des automates de ventes", None, 1_000, None, "25%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Disponibilité des équipements de validation", None, 1_000, None, "25%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Efficacité des lignes de CAB", None, 2_000, None, "50%", "Ligne", "Mensuelle"],
    ["Elévatique", None, 3, None, "3,0%", "Escaliers mécaniques : disponibilité", None, 900, None, "30%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Escaliers mécaniques : délai de remise en service", None, 450, None, "15%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Escaliers mécaniques : affichage date de remise en service", None, 150, None, "5%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Ascenseurs : disponibilité", None, 900, None, "30%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Ascenseurs : délai de remise en service", None, 450, None, "15%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Ascenseurs : affichage date de remise en service", None, 150, None, "5%", "Ligne", "Mensuelle"],
    ["Propreté", None, 3, None, "3,0%", "Propreté des gares", None, 1_500, None, "50%", "Ligne", "Trimestrielle"],
    [None, None, None, None, None, "Propreté des trains", None, 1_500, None, "50%", "Ligne", "Trimestrielle"],
    ["Contact voyageurs", None, 2, None, "2,0%", "Qualité du contact voyageurs en gare", None, 400, None, "20%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Qualité du contact voyageurs à distance", None, 400, None, "20%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Délai du contact voyageurs en gare (5mn) et à distance (1mn)", None, 1_200, None, "60%", "Ligne", "Mensuelle"],
    ["Sûreté", None, 0.5, None, "0,5%", "Disponibilité des bornes d’alarme", None, 250, None, "50%", "Ligne", "Mensuelle"],
    [None, None, None, None, None, "Disponibilité des équipements de vidéoprotection", None, 250, None, "50%", "Ligne", "Mensuelle"],
    ["Noctilien", 0.5, "0,5%", "Information statique aux points d'arrêt", 30, "6%", "Transilien", "Annuelle"],
    [None, None, None, "Information statique à bord", 30, "6%", "Transilien", "Annuelle"],
    [None, None, None, "Information dynamique à bord", 30, "6%", "Transilien", "Annuelle"],
    [None, None, None, "Information en situation perturbée prévue", 60, "12%", "Transilien", "Annuelle"],
    [None, None, None, "Arrêt aux trottoirs", 75, "15%", "Transilien", "Annuelle"],
    [None, None, None, "Disponibilité des plateformes élévatrices", 20, "4%", "Transilien", "Annuelle"],
    [None, None, None, "Propreté des véhicules", 75, "15%", "Transilien", "Annuelle"],
    [None, None, None, "Qualité du contact voyageurs", 180, "36%", "Transilien", "Annuelle"],
    ["Perception des voyageurs", 25, "25%", "Enquête perception", 25_000, "100%", "Ligne", "Annuelle"]
]

# Convertir les données en DataFrame
df = pd.DataFrame(data)

# Nettoyer les données en supprimant les lignes vides et réindexer
df_clean = df.dropna(how='all')  # Supprimer les lignes contenant uniquement des NaN
df_clean.columns = ["Thématiques", None, "Montant (M€)", None, "Poids de la thématique", None, "Indicateurs", None, "Montant (k€)", None, "Poids de l’indicateur", None, "Maille et périodicité"]

# Affichage du DataFrame nettoyé
print(df_clean)

# Sauvegarder en fichier Excel si nécessaire
df_clean.to_excel("tableau_nettoye.xlsx", index=False)
# Out:
#                          Thématiques         None  Montant (M€)  \
# 0                        Thématiques         None  Montant (M€)
# 1                               None  Thématiques          None
# 2   Qualité de l’offre / Ponctualité         None            50
# 3              Information voyageurs         None            12
# 4                               None         None          None
# 5                               None         None          None
# 6                               None         None          None
# 7                               None         None          None
# 8                               None         None          None
# 9                               None         None          None
# 10               Vente / validations         None             4
# 11                              None         None          None
# 12                              None         None          None
# 13                        Elévatique         None             3
# 14                              None         None          None
# 15                              None         None          None
# 16                              None         None          None
# 17                              None         None          None
# 18                              None         None          None
# 19                          Propreté         None             3
# 20                              None         None          None
# 21                 Contact voyageurs         None             2
# 22                              None         None          None
# 23                              None         None          None
# 24                            Sûreté         None           0.5
# 25                              None         None          None
# 26                         Noctilien          0.5          0,5%
# 27                              None         None          None
# 28                              None         None          None
# 29                              None         None          None
# 30                              None         None          None
# 31                              None         None          None
# 32                              None         None          None
# 33                              None         None          None
# 34          Perception des voyageurs           25           25%
#
#                                          None  Poids de la thématique  \
# 0                                        None  poids de la thématique
# 1                         dans le système QS*                    None
# 2                                        None                     50%
# 3                                        None                   12,0%
# 4                                        None                    None
# 5                                        None                    None
# 6                                        None                    None
# 7                                        None                    None
# 8                                        None                    None
# 9                                        None                    None
# 10                                       None                    4,0%
# 11                                       None                    None
# 12                                       None                    None
# 13                                       None                    3,0%
# 14                                       None                    None
# 15                                       None                    None
# 16                                       None                    None
# 17                                       None                    None
# 18                                       None                    None
# 19                                       None                    3,0%
# 20                                       None                    None
# 21                                       None                    2,0%
# 22                                       None                    None
# 23                                       None                    None
# 24                                       None                    0,5%
# 25                                       None                    None
# 26    Information statique aux points d'arrêt                      30
# 27                Information statique à bord                      30
# 28               Information dynamique à bord                      30
# 29  Information en situation perturbée prévue                      60
# 30                        Arrêt aux trottoirs                      75
# 31  Disponibilité des plateformes élévatrices                      20
# 32                     Propreté des véhicules                      75
# 33               Qualité du contact voyageurs                     180
# 34                         Enquête perception                   25000
#
#                                                  None  Indicateurs      None  \
# 0                                                None  Indicateurs      None
# 1                                                None         None      None
# 2                                     Cf ANNEXE I-A-8         None     50000
# 3                Information statique en gare/station         None      1200
# 4                         Information statique à bord         None      1200
# 5               Information dynamique en gare/station         None      2400
# 6                        Information dynamique à bord         None      2400
# 7                       Information en cas de travaux         None      1200
# 8                        Information en cas de grèves         None      1200
# 9                  Information en situation perturbée         None      2400
# 10             Fonctionnement des automates de ventes         None      1000
# 11        Disponibilité des équipements de validation         None      1000
# 12                       Efficacité des lignes de CAB         None      2000
# 13               Escaliers mécaniques : disponibilité         None       900
# 14  Escaliers mécaniques : délai de remise en service         None       450
# 15  Escaliers mécaniques : affichage date de remis...         None       150
# 16                         Ascenseurs : disponibilité         None       900
# 17            Ascenseurs : délai de remise en service         None       450
# 18   Ascenseurs : affichage date de remise en service         None       150
# 19                                 Propreté des gares         None      1500
# 20                                Propreté des trains         None      1500
# 21               Qualité du contact voyageurs en gare         None       400
# 22            Qualité du contact voyageurs à distance         None       400
# 23  Délai du contact voyageurs en gare (5mn) et à ...         None      1200
# 24                  Disponibilité des bornes d’alarme         None       250
# 25   Disponibilité des équipements de vidéoprotection         None       250
# 26                                                 6%   Transilien  Annuelle
# 27                                                 6%   Transilien  Annuelle
# 28                                                 6%   Transilien  Annuelle
# 29                                                12%   Transilien  Annuelle
# 30                                                15%   Transilien  Annuelle
# 31                                                 4%   Transilien  Annuelle
# 32                                                15%   Transilien  Annuelle
# 33                                                36%   Transilien  Annuelle
# 34                                               100%        Ligne  Annuelle
#
#     Montant (k€)  None  Poids de l’indicateur             None  \
# 0   Montant (k€)  None  poids de l’indicateur             None
# 1           None  None                   None             None
# 2           None   50%        Cf ANNEXE I-A-8  Cf ANNEXE I-A-8
# 3           None   10%                  Ligne        Mensuelle
# 4           None   10%                  Ligne        Mensuelle
# 5           None   20%                  Ligne        Mensuelle
# 6           None   20%                  Ligne        Mensuelle
# 7           None   10%                  Ligne        Mensuelle
# 8           None   10%                  Ligne        Mensuelle
# 9           None   20%                  Ligne        Mensuelle
# 10          None   25%                  Ligne        Mensuelle
# 11          None   25%                  Ligne        Mensuelle
# 12          None   50%                  Ligne        Mensuelle
# 13          None   30%                  Ligne        Mensuelle
# 14          None   15%                  Ligne        Mensuelle
# 15          None    5%                  Ligne        Mensuelle
# 16          None   30%                  Ligne        Mensuelle
# 17          None   15%                  Ligne        Mensuelle
# 18          None    5%                  Ligne        Mensuelle
# 19          None   50%                  Ligne    Trimestrielle
# 20          None   50%                  Ligne    Trimestrielle
# 21          None   20%                  Ligne        Mensuelle
# 22          None   20%                  Ligne        Mensuelle
# 23          None   60%                  Ligne        Mensuelle
# 24          None   50%                  Ligne        Mensuelle
# 25          None   50%                  Ligne        Mensuelle
# 26          None  None                   None             None
# 27          None  None                   None             None
# 28          None  None                   None             None
# 29          None  None                   None             None
# 30          None  None                   None             None
# 31          None  None                   None             None
# 32          None  None                   None             None
# 33          None  None                   None             None
# 34          None  None                   None             None
#
#                     Maille et périodicité
# 0   Maille et périodicité de l’indicateur
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# 5                                    None
# 6                                    None
# 7                                    None
# 8                                    None
# 9                                    None
# 10                                   None
# 11                                   None
# 12                                   None
# 13                                   None
# 14                                   None
# 15                                   None
# 16                                   None
# 17                                   None
# 18                                   None
# 19                                   None
# 20                                   None
# 21                                   None
# 22                                   None
# 23                                   None
# 24                                   None
# 25                                   None
# 26                                   None
# 27                                   None
# 28                                   None
# 29                                   None
# 30                                   None
# 31                                   None
# 32                                   None
# 33                                   None
# 34                                   None

# %%
df_clean
# Out:
#                          Thématiques         None  Montant (M€)  \
# 0                        Thématiques         None  Montant (M€)
# 1                               None  Thématiques          None
# 2   Qualité de l’offre / Ponctualité         None            50
# 3              Information voyageurs         None            12
# 4                               None         None          None
# 5                               None         None          None
# 6                               None         None          None
# 7                               None         None          None
# 8                               None         None          None
# 9                               None         None          None
# 10               Vente / validations         None             4
# 11                              None         None          None
# 12                              None         None          None
# 13                        Elévatique         None             3
# 14                              None         None          None
# 15                              None         None          None
# 16                              None         None          None
# 17                              None         None          None
# 18                              None         None          None
# 19                          Propreté         None             3
# 20                              None         None          None
# 21                 Contact voyageurs         None             2
# 22                              None         None          None
# 23                              None         None          None
# 24                            Sûreté         None           0.5
# 25                              None         None          None
# 26                         Noctilien          0.5          0,5%
# 27                              None         None          None
# 28                              None         None          None
# 29                              None         None          None
# 30                              None         None          None
# 31                              None         None          None
# 32                              None         None          None
# 33                              None         None          None
# 34          Perception des voyageurs           25           25%
#
#                                          None  Poids de la thématique  \
# 0                                        None  poids de la thématique
# 1                         dans le système QS*                    None
# 2                                        None                     50%
# 3                                        None                   12,0%
# 4                                        None                    None
# 5                                        None                    None
# 6                                        None                    None
# 7                                        None                    None
# 8                                        None                    None
# 9                                        None                    None
# 10                                       None                    4,0%
# 11                                       None                    None
# 12                                       None                    None
# 13                                       None                    3,0%
# 14                                       None                    None
# 15                                       None                    None
# 16                                       None                    None
# 17                                       None                    None
# 18                                       None                    None
# 19                                       None                    3,0%
# 20                                       None                    None
# 21                                       None                    2,0%
# 22                                       None                    None
# 23                                       None                    None
# 24                                       None                    0,5%
# 25                                       None                    None
# 26    Information statique aux points d'arrêt                      30
# 27                Information statique à bord                      30
# 28               Information dynamique à bord                      30
# 29  Information en situation perturbée prévue                      60
# 30                        Arrêt aux trottoirs                      75
# 31  Disponibilité des plateformes élévatrices                      20
# 32                     Propreté des véhicules                      75
# 33               Qualité du contact voyageurs                     180
# 34                         Enquête perception                   25000
#
#                                                  None  Indicateurs      None  \
# 0                                                None  Indicateurs      None
# 1                                                None         None      None
# 2                                     Cf ANNEXE I-A-8         None     50000
# 3                Information statique en gare/station         None      1200
# 4                         Information statique à bord         None      1200
# 5               Information dynamique en gare/station         None      2400
# 6                        Information dynamique à bord         None      2400
# 7                       Information en cas de travaux         None      1200
# 8                        Information en cas de grèves         None      1200
# 9                  Information en situation perturbée         None      2400
# 10             Fonctionnement des automates de ventes         None      1000
# 11        Disponibilité des équipements de validation         None      1000
# 12                       Efficacité des lignes de CAB         None      2000
# 13               Escaliers mécaniques : disponibilité         None       900
# 14  Escaliers mécaniques : délai de remise en service         None       450
# 15  Escaliers mécaniques : affichage date de remis...         None       150
# 16                         Ascenseurs : disponibilité         None       900
# 17            Ascenseurs : délai de remise en service         None       450
# 18   Ascenseurs : affichage date de remise en service         None       150
# 19                                 Propreté des gares         None      1500
# 20                                Propreté des trains         None      1500
# 21               Qualité du contact voyageurs en gare         None       400
# 22            Qualité du contact voyageurs à distance         None       400
# 23  Délai du contact voyageurs en gare (5mn) et à ...         None      1200
# 24                  Disponibilité des bornes d’alarme         None       250
# 25   Disponibilité des équipements de vidéoprotection         None       250
# 26                                                 6%   Transilien  Annuelle
# 27                                                 6%   Transilien  Annuelle
# 28                                                 6%   Transilien  Annuelle
# 29                                                12%   Transilien  Annuelle
# 30                                                15%   Transilien  Annuelle
# 31                                                 4%   Transilien  Annuelle
# 32                                                15%   Transilien  Annuelle
# 33                                                36%   Transilien  Annuelle
# 34                                               100%        Ligne  Annuelle
#
#     Montant (k€)  None  Poids de l’indicateur             None  \
# 0   Montant (k€)  None  poids de l’indicateur             None
# 1           None  None                   None             None
# 2           None   50%        Cf ANNEXE I-A-8  Cf ANNEXE I-A-8
# 3           None   10%                  Ligne        Mensuelle
# 4           None   10%                  Ligne        Mensuelle
# 5           None   20%                  Ligne        Mensuelle
# 6           None   20%                  Ligne        Mensuelle
# 7           None   10%                  Ligne        Mensuelle
# 8           None   10%                  Ligne        Mensuelle
# 9           None   20%                  Ligne        Mensuelle
# 10          None   25%                  Ligne        Mensuelle
# 11          None   25%                  Ligne        Mensuelle
# 12          None   50%                  Ligne        Mensuelle
# 13          None   30%                  Ligne        Mensuelle
# 14          None   15%                  Ligne        Mensuelle
# 15          None    5%                  Ligne        Mensuelle
# 16          None   30%                  Ligne        Mensuelle
# 17          None   15%                  Ligne        Mensuelle
# 18          None    5%                  Ligne        Mensuelle
# 19          None   50%                  Ligne    Trimestrielle
# 20          None   50%                  Ligne    Trimestrielle
# 21          None   20%                  Ligne        Mensuelle
# 22          None   20%                  Ligne        Mensuelle
# 23          None   60%                  Ligne        Mensuelle
# 24          None   50%                  Ligne        Mensuelle
# 25          None   50%                  Ligne        Mensuelle
# 26          None  None                   None             None
# 27          None  None                   None             None
# 28          None  None                   None             None
# 29          None  None                   None             None
# 30          None  None                   None             None
# 31          None  None                   None             None
# 32          None  None                   None             None
# 33          None  None                   None             None
# 34          None  None                   None             None
#
#                     Maille et périodicité
# 0   Maille et périodicité de l’indicateur
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# 5                                    None
# 6                                    None
# 7                                    None
# 8                                    None
# 9                                    None
# 10                                   None
# 11                                   None
# 12                                   None
# 13                                   None
# 14                                   None
# 15                                   None
# 16                                   None
# 17                                   None
# 18                                   None
# 19                                   None
# 20                                   None
# 21                                   None
# 22                                   None
# 23                                   None
# 24                                   None
# 25                                   None
# 26                                   None
# 27                                   None
# 28                                   None
# 29                                   None
# 30                                   None
# 31                                   None
# 32                                   None
# 33                                   None
# 34                                   None

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {
            "role": "user",
            "content": "Write a haiku about recursion in programming."
        }
    ]
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 from openai import OpenAI
# ----> 2 client = OpenAI()
#       4 completion = client.chat.completions.create(
#       5     model="gpt-4o-mini",
#       6     messages=[
#    (...)
#      12     ]
#      13 )
#      15 print(completion.choices[0].message)
#
# File ~/Library/CloudStorage/OneDrive-BearingPointGmbH/IDFM/DataHub/QSindicators/.venv/lib/python3.12/site-packages/openai/_client.py:105, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     103     api_key = os.environ.get("OPENAI_API_KEY")
#     104 if api_key is None:
# --> 105     raise OpenAIError(
#     106         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     107     )
#     108 self.api_key = api_key
#     110 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
